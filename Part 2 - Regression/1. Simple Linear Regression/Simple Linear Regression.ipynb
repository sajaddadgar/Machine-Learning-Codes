# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# **1. Data Preprocessing**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# we don't have missing and categorical data
# we don't implement feature scaling because the library that we use implement it
dataframe = pd.read_csv('Salary_Data.csv')
X = dataframe.iloc[:, :-1].values
y = dataframe.iloc[:, 1].values
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0)

# %% [markdown]
# **2. Linear Regression With One Feature**
# <br>
#     **2.1. Fitting Data**

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %% [markdown]
# **2.2. Prediction**

# %%
y_prediction = regressor.predict(x_test)
y_prediction
# Out:
# array([ 40835.10590871, 123079.39940819,  65134.55626083,  63265.36777221,
#        115602.64545369, 108125.8914992 , 116537.23969801,  64199.96201652,
#         76349.68719258, 100649.1375447 ])

# %% [markdown]
# **3. Visualization**

# %%
# plt.figure(figsize=(8,3))
plt.scatter(x_train, y_train, color='red')
prediction_of_x_train = regressor.predict(x_train)
plt.plot(x_train, prediction_of_x_train, color='blue')
plt.title('Salary vs Exprience (training set)')
plt.xlabel('Years of Exprience')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(x_test, y_test, color='red')
# same line
plt.plot(x_train, prediction_of_x_train, color='blue')
plt.title('Salary vs Exprience (test set)')
plt.xlabel('Years of Exprience')
plt.ylabel('Salary')
plt.show()
